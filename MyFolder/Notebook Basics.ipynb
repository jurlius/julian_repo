# %%
print("Hello World")

# %%
# %sql
select "SELECT FROM SQL!"

# %% [markdown]
# # Title 1
# Test . sajdbkabda
# ## Title 2

# %%
# %run ./Includes/setup

# %%
print(full_name)

# %%
dbutils.help()

# %%
dbutils.fs.help()

# %%
files = dbutils.fs.ls("/databricks-datasets/")
print(files)

# %%
display(files)
